# %%
import numpy as np
import matplotlib.pyplot as plt

x_data = [1.0,2.0,3.0]
y_data = [2.0,4.0,6.0]

w = 1.0

def forward(x):
    return x * w

def cost(xs,ys):
    cost = 0
    for x, y in zip (xs,ys):
        y_pred = forward(x)
        cost += (y_pred - y) ** 2
    return cost / len(xs)

def gradient(xs,ys):
    grad = 0    
    for x, y in zip (xs,ys):
        grad = 2 * x * (x * w - y)
    return grad / len(xs)

print('Predict (before training)', 4, forward(4))

loss = []
for epoch in range(100):
    cost_val = cost(x_data,y_data)
    grad_val = gradient(x_data,y_data)
    w -= 0.01 * grad_val
    print('Epoch:',epoch, 'w=', w, 'loss=', cost_val)
    loss.append(cost_val)
    
print('Predict (after training)', 4, forward(4))

plt.plot(loss)
plt.grid(True)
plt.ylabel('cost')
plt.xlabel('epoch')
plt.show()
# Out:
# Predict (before training) 4 4.0
# Epoch: 0 w= 1.06 loss= 4.666666666666667
# Epoch: 1 w= 1.1164 loss= 4.123466666666666
# Epoch: 2 w= 1.169416 loss= 3.643495146666666
# Epoch: 3 w= 1.21925104 loss= 3.219392311594666
# Epoch: 4 w= 1.2660959776 loss= 2.844655046525047
# Epoch: 5 w= 1.310130218944 loss= 2.513537199109532
# Epoch: 6 w= 1.35152240580736 loss= 2.2209614691331816
# Epoch: 7 w= 1.3904310614589184 loss= 1.96244155412608
# Epoch: 8 w= 1.4270051977713833 loss= 1.7340133572258043
# Epoch: 9 w= 1.4613848859051004 loss= 1.5321742024447207
# Epoch: 10 w= 1.4937017927507943 loss= 1.3538291252801544
# Epoch: 11 w= 1.5240796851857465 loss= 1.1962434150975454
# Epoch: 12 w= 1.5526349040746017 loss= 1.0570006815801913
# Epoch: 13 w= 1.5794768098301255 loss= 0.9339658022442568
# Epoch: 14 w= 1.604708201240318 loss= 0.8252521828630258
# Epoch: 15 w= 1.628425709165899 loss= 0.7291928287777699
# Epoch: 16 w= 1.650720166615945 loss= 0.6443147835080376
# Epoch: 17 w= 1.6716769566189884 loss= 0.5693165427077015
# Epoch: 18 w= 1.691376339221849 loss= 0.5030480971365248
# Epoch: 19 w= 1.7098937588685381 loss= 0.4444932986298335
# Epoch: 20 w= 1.7273001333364257 loss= 0.3927542786693208
# Epoch: 21 w= 1.74366212533624 loss= 0.34703768063221235
# Epoch: 22 w= 1.7590423978160656 loss= 0.3066424946066227
# Epoch: 23 w= 1.7734998539471016 loss= 0.27094930823441205
# Epoch: 24 w= 1.7870898627102756 loss= 0.23941080875592669
# Epoch: 25 w= 1.799864470947659 loss= 0.2115433906167367
# Epoch: 64 w= 1.982081135558726 loss= 0.001695789889884772
# Epoch: 65 w= 1.9831562674252023 loss= 0.0014983999467021837
# Epoch: 66 w= 1.9841668913796902 loss= 0.0013239861929060573
# Epoch: 67 w= 1.9851168778969088 loss= 0.001169874200051806
# Epoch: 68 w= 1.9860098652230942 loss= 0.0010337008431657582
# Epoch: 69 w= 1.9868492733097085 loss= 0.0009133780650212832
# Epoch: 70 w= 1.987638316911126 loss= 0.00080706085825281
# Epoch: 71 w= 1.9883800178964586 loss= 0.0007131189743521854
# Epoch: 72 w= 1.9890772168226711 loss= 0.0006301119257375792
# Epoch: 73 w= 1.9897325838133109 loss= 0.000556766897581708
# Epoch: 74 w= 1.9903486287845122 loss= 0.0004919592307031973
# Epoch: 75 w= 1.9909277110574415 loss= 0.0004346951762493507
# Epoch: 76 w= 1.991472048393995 loss= 0.00038409665773392435
# Epoch: 77 w= 1.9919837254903552 loss= 0.0003393878067736922
# Epoch: 78 w= 1.9924647019609338 loss= 0.00029988306606524575
# Epoch: 79 w= 1.9929168198432778 loss= 0.0002649766771752537
# Epoch: 80 w= 1.9933418106526812 loss= 0.00023413339195205176
# Epoch: 81 w= 1.9937413020135204 loss= 0.00020688026512882615
# Epoch: 82 w= 1.9941168238927092 loss= 0.0001827994022678255
# Epoch: 83 w= 1.9944698144591466 loss= 0.00016152155184385078
# Epoch: 84 w= 1.994801625591598 loss= 0.00014272044320923363
# Epoch: 85 w= 1.995113528056102 loss= 0.00012610778361967257
# Epoch: 86 w= 1.995406716372736 loss= 0.00011142883760633769
# Epoch: 87 w= 1.9956823133903718 loss= 9.845852090896108e-05
# Epoch: 88 w= 1.9959413745869494 loss= 8.699794907515781e-05
# Epoch: 89 w= 1.9961848921117324 loss= 7.687138780281135e-05
# Epoch: 90 w= 1.9964137985850285 loss= 6.792355826256616e-05
# Epoch: 91 w= 1.9966289706699267 loss= 6.001725608080358e-05
# Epoch: 92 w= 1.996831232429731 loss= 5.3031247473001334e-05
# Epoch: 93 w= 1.9970213584839471 loss= 4.685841026714374e-05
# Epoch: 94 w= 1.9972000769749103 loss= 4.140409131204818e-05
# Epoch: 95 w= 1.9973680723564158 loss= 3.658465508332787e-05
# Epoch: 96 w= 1.997525988015031 loss= 3.232620123162633e-05
# Epoch: 97 w= 1.997674428734129 loss= 2.8563431408264683e-05
# Epoch: 98 w= 1.9978139630100813 loss= 2.52386479923418e-05
# Epoch: 99 w= 1.9979451252294764 loss= 2.2300869366033213e-05
# Predict (after training) 4 7.991780500917906
